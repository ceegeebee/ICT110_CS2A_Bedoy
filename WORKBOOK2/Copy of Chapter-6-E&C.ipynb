# %% [markdown]
# #### Exercise 1

# %%
#Given the code below

#What will the following expressions produce?

text = 'Business Analytics'


print(text[4])
print(text[2:4])
print(text[:4])
print(text[4:])
print(text[-2])
print(text[-4:-2])
print(text[-2:])
print(text[:-2])

#the expressions above will produce the result below:

 n
 si
 Busi
 ness Analytics
 c
 ti
 cs
 Business Analyti

# %% [markdown]
# #### Exercise 2

# %%
#Given the code below:

#What string slicing expression gives out the following words:

phrase = 'One ring to rule them all'
phrase.split()

# 'One '
#'Ring'
#'all'
#'them'
#'One Ring to rule them all'
# Out:
# ['One', 'ring', 'to', 'rule', 'them', 'all']

# %%
phrase = 'One ring to rule them all'
# 'One '
word1 = phrase[:4]

# 'Ring'
word2 = phrase[4:8]

# 'all'
word3 = phrase[-3:]

# 'them'
word4 = phrase[-8:-3]

# 'One Ring to rule them all'
word5 = phrase.capitalize()

print(word1)
print(word2)
print(word3)
print(word4)
print(word5)
# Out:
# One
# ring
# all
# them
# One ring to rule them all

# %% [markdown]
# ## CHALLENGE

# %% [markdown]
# Write a program which repeatedly reads a **full name**, then does the following:
# - strips the name of any trailing spaces
# - capitalizes the first letter
# - puts the rest into smaller letters

# %%
while True:
    full_name = input("Enter a full name (or 'exit' ): ")


    if full_name.lower() == 'exit':
        print("Exiting program...")
        break


    formatted_name = full_name.strip().capitalize()


    spaceIndex = formatted_name.find(" ")
    if spaceIndex != -1:
        formatted_name = formatted_name[:spaceIndex + 1] + formatted_name[spaceIndex + 1:].lower()

    print("Formatted name:", formatted_name)

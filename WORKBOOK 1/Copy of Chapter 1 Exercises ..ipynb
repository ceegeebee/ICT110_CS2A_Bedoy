# %% [markdown]
# CHAPTER 1

# %% [markdown]
# #### Exercise 1
#
# Each line of code below contains an error. Fix the error and explain in a comment the reason for the error.

# %%
print("Hello world!") #the letter P is in Uppercase
# Out:
# Hello world!

# %%
print("Hello world!") #the quote is missing after print
# Out:
# Hello world!

# %%
print("Hello world!") #there is a missing quote at the end of !
# Out:
# Hello world!

# %%
print("Hello world!") # It should be a single or double quote before and after the Variable inside the parentheses
# Out:
# Hello world

# %% [markdown]
# #### Exercise 2
# What is the output of the code below? [PEW]

# %%
x = 43
x = x + 1
print(x) # the output of this code is 44 (x=44)
# Out:
# 44

# %% [markdown]
# #### Exercise 3
# The code below contains an error. Fix the error and explain in a comment the reason for the error.

# %%
x = 43
x = X + 1 # the variable X is undefined
print(x)

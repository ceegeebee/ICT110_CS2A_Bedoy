# %% [markdown]
# ## EXERCISES

# %% [markdown]
# #### Exercise 1
# Adapted from [TCS] Appendix D, Exercise 2
#
# Open help for the math module.
#
# - What are the constants in the math module?
# - What's does `math.exp` do? What about `math.pow`?
# - How do you calculate logarithms? Logarithms base 10? Natural Logarithms?

# %%
# 1. What are the constants in the math module?
#Answer: math.pi , math.e , math.sqrt, and math.sin

# 2. What's does math.exp do? What about math.pow?
#Answer: math.exp returns the exponential of x, which is equivalent to e raised to the power of x.
     #   math.pow returns x raised to the power of y

# 3. How do you calculate logarithms? Logarithms base 10? Natural Logarithms?
#Answer: Logarithms: You can calculate logarithms using the math.log(x, base) function.
      #  Logarithms base 10: You can use math.log10(x) to calculate the base-10 logarithm of x.
      #  Natural logarithms: The natural logarithm (base e) of x can be calculated using math.log(x)

# %% [markdown]
# #### Exercise 2
# - Create your own module.
# - Place variables and functions inside it.
# - Import your module and use the variabls and functions you've created in the module.
# - Try to add docstrings for the module and the functions
#
# [あ]

# %%
# %%writefile ownmodule.py

"""
My Own Module
"""

# Define some variables
favorite_number = 30
greeting = "Konnichiwa"


# Define a function to double a number
def double_number(x):
    """
    Doubles the input number.

    Args:
        x (int or float): The number to be doubled.

    Returns:
        int or float: The result of doubling the input number.
    """
    return x * 2

# Define a function to greet a person
def greet_person(name):
    """
    Generates a personalized greeting message for the given name.

    Args:
        name (str): The name of the person to greet.

    Returns:
        str: The greeting message.
    """
    return f"Hello, {name}! Nice to meet you."
# Out:
# Overwriting ownmodule.py

# %%
# !ls -l ownmodule.py
# Out:
# -rw-r--r-- 1 root root 693 Apr 13 18:08 ownmodule.py

# %%
# !dir ownmodule.py
# Out:
# ownmodule.py

# %%
import ownmodule

# %%
ownmodule.greeting
# Out:
# 'Konnichiwa'

# %%
ownmodule.favorite_number
# Out:
# 30

# %%
import ownmodule


print("Favorite number:", ownmodule.favorite_number)
print("Greeting message:", ownmodule.greeting)


number = 5
print(f"Doubling {number}:", ownmodule.double_number(number))

name = "Alice"
print(ownmodule.greet_person(name))
# Out:
# Favorite number: 30
# Greeting message: Konnichiwa
# Doubling 5: 10
# Hello, Alice! Nice to meet you.

# %% [markdown]
# [TABLE OF CONTENTS](#contents)
